# %% [markdown]
# # Australia Car Market Dataset:-

# %% [markdown]
# 1. PRICE DISTRIBUTION
# 2. BRAND POPULARITY
# 3. WHICH TYPES OF COLLECATION IN CARS
# 4. WHICH TYPES OF CAR IN AUSTRALIA
# 5. CHECK CAR STATUS
# 6. VARIATIONS IN CC'S OF CARS
# 7. SEATING CAPACITY DISTRIBUTION
# 8. PRICE DISTRIBUTION WITH RESPECT TO EACH BRAND
# 9. CC ENGINE DISTRIBUTION WITH RESPECT TO EACH BRAND
# 10. EDA
# 11. BIVARIANT ANALYSIS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ac = pd.read_csv(r"C:\Users\ASUS\Downloads\Australian Car Pridiction\cars_info.csv")

# %%
ac
# Out:
#              ID                                               Name   Price  \
# 0      11530130                  2010 Toyota Rukus Build 2 AZE151R    9999
# 1      12190570  2021 Mercedes-Benz V 250 D Avantgarde MWB 447 ...  117990
# 2      12321855  2021 Mercedes-Benz Valente 116 CDI MWB RWD 447...   79990
# 3      12346971         2010 Mercedes-Benz E250 CDI Avantgarde 207   34990
# 4      12363884                       2016 Holden Cruze CD JH MY16   15990
# ...         ...                                                ...     ...
# 17043  12852453                 2003 Holden Commodore Executive VY    4499
# 17044  12852460                        2008 Toyota Yaris YR NCP90R    4999
# 17045  12852462               2002 Holden Jackaroo SE LWB (4X4) U8    7999
# 17046  12852463               2016 Hyundai I30 Active GD4 Series 2   14000
# 17047  12852464              2005 Toyota RAV4 Cruiser (4X4) ACA23R    5999
#
# ...

# %%
ac.columns
# Out:
# Index(['ID', 'Name', 'Price', 'Brand', 'Model', 'Variant', 'Series', 'Year',
#        'Kilometers', 'Type', 'Gearbox', 'Fuel', 'Status', 'CC', 'Color',
#        'Seating Capacity'],
#       dtype='object')

# %%
ac.describe(include = "all")
# Out:
#                   ID                                       Name  \
# count   1.704800e+04                                      17048
# unique           NaN                                       8575
# top              NaN  2018 Nissan X-Trail ST (2WD) T32 Series 2
# freq             NaN                                         33
# mean    1.279027e+07                                        NaN
# std     5.051111e+04                                        NaN
# min     1.153013e+07                                        NaN
# 25%     1.275715e+07                                        NaN
# 50%     1.280207e+07                                        NaN
# 75%     1.283131e+07                                        NaN
# max     1.285246e+07                                        NaN
#
#                 Price   Brand   Model Variant Series          Year  \
# count    17048.000000   17048   17048   17048  17048  17048.000000
# ...

# %%
ac.dropna(how = "any",inplace = True)
ac.isnull().sum()
# Out:
# ID                  0
# Name                0
# Price               0
# Brand               0
# Model               0
# Variant             0
# Series              0
# Year                0
# Kilometers          0
# Type                0
# Gearbox             0
# Fuel                0
# Status              0
# CC                  0
# Color               0
# Seating Capacity    0
# dtype: int64

# %%
ac.head(5)
# Out:
#          ID                                               Name   Price  \
# 0  11530130                  2010 Toyota Rukus Build 2 AZE151R    9999
# 1  12190570  2021 Mercedes-Benz V 250 D Avantgarde MWB 447 ...  117990
# 2  12321855  2021 Mercedes-Benz Valente 116 CDI MWB RWD 447...   79990
# 3  12346971         2010 Mercedes-Benz E250 CDI Avantgarde 207   34990
# 4  12363884                       2016 Holden Cruze CD JH MY16   15990
#
#            Brand    Model               Variant    Series  Year  Kilometers  \
# 0         Toyota    Rukus               Build 2   AZE151R  2010      263000
# 1  Mercedes-Benz        V  250 D Avantgarde MWB  447 MY21  2021          19
# 2  Mercedes-Benz  Valente       116 CDI MWB RWD  447 MY21  2021          24
# 3  Mercedes-Benz     E250        CDI Avantgarde       207  2010      120579
# 4         Holden    Cruze                    CD   JH MY16  2016       72506
#
#           Type    Gearbox             Fuel         Status    CC  Color  \
# ...

# %%
ac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17048 entries, 0 to 17047
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                17048 non-null  int64
#  1   Name              17048 non-null  object
#  2   Price             17048 non-null  int64
#  3   Brand             17048 non-null  object
#  4   Model             17048 non-null  object
#  5   Variant           17048 non-null  object
#  6   Series            17048 non-null  object
#  7   Year              17048 non-null  int64
#  8   Kilometers        17048 non-null  int64
#  9   Type              17048 non-null  object
#  10  Gearbox           17048 non-null  object
#  11  Fuel              17048 non-null  object
#  12  Status            17048 non-null  object
#  13  CC                17048 non-null  int64
#  14  Color             17048 non-null  object
#  15  Seating Capacity  17048 non-null  int64
# ...

# %% [markdown]
# # DATA CLEANING:-

# %%
ac.dtypes
# Out:
# ID                   int64
# Name                object
# Price                int64
# Brand               object
# Model               object
# Variant             object
# Series              object
# Year                 int64
# Kilometers           int64
# Type                object
# Gearbox             object
# Fuel                object
# Status              object
# CC                   int64
# Color               object
# Seating Capacity     int64
# dtype: object

# %%
ac["Brand"].unique()
# Out:
# array(['Toyota', 'Mercedes-Benz', 'Holden', 'Nissan', 'Ford', 'BMW',
#        'Isuzu', 'Hyundai', 'Volkswagen', 'Lexus', 'Mazda', 'Audi',
#        'Subaru', 'Mitsubishi', 'Kia', 'Skoda', 'Renault', 'Porsche',
#        'Jeep', 'Honda', 'Ssangyong', 'Volvo', 'Land Rover', 'MG',
#        'Suzuki', 'Ram', 'Mini', 'Jaguar', 'LDV', 'HSV', 'Alfa Romeo',
#        'Aston Martin', 'Hino', 'Chrysler', 'Citroen', 'Infiniti',
#        'Peugeot', 'Chevrolet', 'Lamborghini', 'Fiat', 'Bentley', 'Dodge',
#        'Haval', 'Great Wall', 'Abarth', 'Foton', 'Genesis', 'GWM', 'FPV',
#        'Mitsubishi Fuso', 'Maserati', 'Iveco', 'Mahindra', 'Opel', 'Saab',
#        'Chery', 'Smart', 'Proton', 'Cupra'], dtype=object)

# %%
ac.head()
# Out:
#          ID                                               Name   Price  \
# 0  11530130                  2010 Toyota Rukus Build 2 AZE151R    9999
# 1  12190570  2021 Mercedes-Benz V 250 D Avantgarde MWB 447 ...  117990
# 2  12321855  2021 Mercedes-Benz Valente 116 CDI MWB RWD 447...   79990
# 3  12346971         2010 Mercedes-Benz E250 CDI Avantgarde 207   34990
# 4  12363884                       2016 Holden Cruze CD JH MY16   15990
#
#            Brand    Model               Variant    Series  Year  Kilometers  \
# 0         Toyota    Rukus               Build 2   AZE151R  2010      263000
# 1  Mercedes-Benz        V  250 D Avantgarde MWB  447 MY21  2021          19
# 2  Mercedes-Benz  Valente       116 CDI MWB RWD  447 MY21  2021          24
# 3  Mercedes-Benz     E250        CDI Avantgarde       207  2010      120579
# 4         Holden    Cruze                    CD   JH MY16  2016       72506
#
#           Type    Gearbox             Fuel         Status    CC  Color  \
# ...

# %%
ac.shape
# Out:
# (17048, 16)

# %%
ac.size
# Out:
# 272768

# %%
ac.describe()
# Out:
#                  ID          Price          Year    Kilometers            CC  \
# count  1.704800e+04   17048.000000  17048.000000  1.704800e+04  17048.000000
# mean   1.279027e+07   36777.778038   2015.481288  1.032314e+05   2491.830303
# std    5.051111e+04   30305.015328      4.721591  8.041313e+04    881.985562
# min    1.153013e+07    1000.000000   1989.000000  1.000000e+00    875.000000
# 25%    1.275715e+07   18800.000000   2013.000000  4.450225e+04   1987.000000
# 50%    1.280207e+07   29990.000000   2016.000000  8.845400e+04   2354.000000
# 75%    1.283131e+07   45990.000000   2019.000000  1.488735e+05   2981.000000
# max    1.285246e+07  999000.000000   2022.000000  2.700000e+06   7300.000000
#
#        Seating Capacity
# count      17048.000000
# mean           5.115849
# std            1.121791
# min            2.000000
# 25%            5.000000
# 50%            5.000000
# 75%            5.000000
# max           14.000000

# %%
ac.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 17043    False
# 17044    False
# 17045    False
# 17046    False
# 17047    False
# Length: 17048, dtype: bool

# %% [markdown]
# # DATA VISUALIZATION:-

# %%
 ac.head()
# Out:
#          ID                                               Name   Price  \
# 0  11530130                  2010 Toyota Rukus Build 2 AZE151R    9999
# 1  12190570  2021 Mercedes-Benz V 250 D Avantgarde MWB 447 ...  117990
# 2  12321855  2021 Mercedes-Benz Valente 116 CDI MWB RWD 447...   79990
# 3  12346971         2010 Mercedes-Benz E250 CDI Avantgarde 207   34990
# 4  12363884                       2016 Holden Cruze CD JH MY16   15990
#
#            Brand    Model               Variant    Series  Year  Kilometers  \
# 0         Toyota    Rukus               Build 2   AZE151R  2010      263000
# 1  Mercedes-Benz        V  250 D Avantgarde MWB  447 MY21  2021          19
# 2  Mercedes-Benz  Valente       116 CDI MWB RWD  447 MY21  2021          24
# 3  Mercedes-Benz     E250        CDI Avantgarde       207  2010      120579
# 4         Holden    Cruze                    CD   JH MY16  2016       72506
#
#           Type    Gearbox             Fuel         Status    CC  Color  \
# ...

# %% [markdown]
# # 1. PRICE DISTRIBUTION

# %%
sns.distplot(ac['Price'])
font = {'family':'serif','color':'red','size':20}
plt.title('Price Distribution',fontdict=font)
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_22676\1302591260.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(ac['Price'])

# %% [markdown]
# # 2. BRAND POPULARITY

# %%
plt.figure(figsize=(20,5))
sns.countplot(data=ac, x='Brand',palette='rainbow')
font = {'family':'serif','color':'green','size':30}
plt.title('Brand Recognition',fontdict=font)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_22676\3349511903.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=ac, x='Brand',palette='rainbow')

# %% [markdown]
# # 3. Which Types of Collecation In Cars

# %%
plt.figure(figsize=(20,5))
sns.countplot(data=ac, x = 'Fuel',)
font = {'family':'serif','color':'black','size':25}
plt.title('Fuel Type Distribution',fontdict=font)
plt.show()

# %% [markdown]
# # 4. Which Types of Car In Australia

# %%
plt.figure(figsize=(20,5))
sns.countplot(x='Type',data=ac,color='olive')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # 5. Check Car Status

# %%
sns.countplot(x = 'Status',data=ac,palette='rainbow')
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_22676\293747311.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'Status',data=ac,palette='rainbow')

# %% [markdown]
# # 6. Variations In CC's Of Cars

# %%
plt.figure(figsize=(10,5))
sns.histplot(ac['CC'])
plt.show()

# %% [markdown]
# # 7. Seating Capacity Distribution

# %%
plt.figure(figsize=(8,5))
sns.histplot(ac['Seating Capacity'])
plt.show()

# %% [markdown]
# # 8. Price Distribution With Respect To Each Brand

# %%
plt.figure(figsize=(20,6))
sns.boxplot(x='Brand', y='Price',data=ac,palette='spring')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_22676\2956222941.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Brand', y='Price',data=ac,palette='spring')

# %% [markdown]
# # 9. CC Engine Distribution With Respect TO Each Brand

# %%
plt.figure(figsize=(20,5))
sns.boxplot(x='Brand', y='CC',data=ac,palette='winter')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_22676\997991217.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Brand', y='CC',data=ac,palette='winter')

# %% [markdown]
# # 10. EDA:-

# %%
ac.hist(figsize = (25,20),color = "olive")
# Out:
# array([[<Axes: title={'center': 'ID'}>,
#         <Axes: title={'center': 'Price'}>],
#        [<Axes: title={'center': 'Year'}>,
#         <Axes: title={'center': 'Kilometers'}>],
#        [<Axes: title={'center': 'CC'}>,
#         <Axes: title={'center': 'Seating Capacity'}>]], dtype=object)

# %%
ac.head(5)
# Out:
#          ID                                               Name   Price  \
# 0  11530130                  2010 Toyota Rukus Build 2 AZE151R    9999
# 1  12190570  2021 Mercedes-Benz V 250 D Avantgarde MWB 447 ...  117990
# 2  12321855  2021 Mercedes-Benz Valente 116 CDI MWB RWD 447...   79990
# 3  12346971         2010 Mercedes-Benz E250 CDI Avantgarde 207   34990
# 4  12363884                       2016 Holden Cruze CD JH MY16   15990
#
#            Brand    Model               Variant    Series  Year  Kilometers  \
# 0         Toyota    Rukus               Build 2   AZE151R  2010      263000
# 1  Mercedes-Benz        V  250 D Avantgarde MWB  447 MY21  2021          19
# 2  Mercedes-Benz  Valente       116 CDI MWB RWD  447 MY21  2021          24
# 3  Mercedes-Benz     E250        CDI Avantgarde       207  2010      120579
# 4         Holden    Cruze                    CD   JH MY16  2016       72506
#
#           Type    Gearbox             Fuel         Status    CC  Color  \
# ...

# %% [markdown]
# # 11. BIVARIANT ANALYSIS:-

# %%
sns.pairplot(ac)
